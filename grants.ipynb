# %%
import tabula
import pandas as pd

# %%
dfs = tabula.read_pdf("Local Government National Report 2021–22.pdf", pages=[1, 2, 3, 4, 5, 6], multiple_tables=True)

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#                     Council name Classification   Number   sq km  in km  \
# 0            Albury City Council            URM   55,055     306    545
# 1      Armidale Regional Council            URM   29,704   7,809  1,727
# 2          Ballina Shire Council            URM   45,217     485    655
# 3        Balranald Shire Council            RAM    2,306  21,691  1,326
# 4      Bathurst Regional Council            URM   43,996   3,818  1,160
# ..                           ...            ...      ...     ...    ...
# 137      Willoughby City Council            UDL   81,196      22    199
# 138  Wingecarribee Shire Council            URM   51,760   2,689  1,080
# 139    Wollondilly Shire Council            UFM   54,005   2,555    741
# 140      Wollongong City Council            URV  219,798     684    984
# 141          Yass Valley Council            RAV   17,321   3,995  1,075
#
#      in dollars in dollars.1     dollars per capita (Yes or No)    per km
# ...
